# %% [markdown]
# # Random graph experiments I: Color

# %% [markdown]
# ## Graph and data generation module ##

# %%
import os
os.environ["OMP_NUM_THREADS"] = "1" # export OMP_NUM_THREADS=4
os.environ["OPENBLAS_NUM_THREADS"] = "1" # export OPENBLAS_NUM_THREADS=4 
os.environ["VECLIB_MAXIMUM_THREADS"] = "1" # export VECLIB_MAXIMUM_THREADS=4

# %%
import sys, time, random
import numpy as np
from model.MNLogit_bfgs_torch import MNLogit

# %%
filenames = sorted([name for name in os.listdir('features-degree-big') if len(name.split('&')) > 3])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-34d1fa417cb0> in <module>()
# ----> 1 filenames = sorted([name for name in os.listdir('features-degree-big') if len(name.split('&')) > 3])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'features-degree-big'

# %%
len(filenames)

# %%
def fit(kwargs, num_threads=1):
  dataset_id = kwargs['id']
  sampling = kwargs['sampling']
  c = sampling[0]
  dat = np.load('features-degree/' + filenames[dataset_id])
  results = {'results':[]}
  results['dataset'] = {s.split('=')[0]:s.split('=')[1] for s in filenames[dataset_id].replace('.npz','').split('&')}
  results['dataset']['sampling'] = sampling
  
  for i in range(20):
    m = MNLogit(num_threads)
    m.data(dat['Xs_'+c][i], dat['ys_'+c][i], sws=dat['sws_'+c][i])
    m.fit(max_num_iter=500, clip=1.0, clip_norm_ord=2)
    info = m.get_model_info()
    info['se'] = list(info['se'])
    info['weights'] = list(info['weights'])
    results['results'].append(info)
    
  print("Dataset {},{} done".format(dataset_id,sampling))
  return results

# %%
from multiprocessing import Pool
from itertools import product
args = [{'id':i, 'sampling':s} for i,s in product(range(len(filenames)), ['uniform','stratified','importance'])]
with Pool(49) as p:
  x = p.map(fit, args)
# Out:
# Dataset 32,uniform done
# Dataset 26,importance done
# Dataset 34,importance done
# Dataset 40,uniform done
# Dataset 20,uniform done
# Dataset 52,uniform done
# Dataset 10,importance done
# Dataset 46,importance done
# Dataset 16,uniform done
# Dataset 50,importance done
# Dataset 21,stratified done
# Dataset 25,stratified done
# Dataset 36,uniform done
# Dataset 53,stratified done
# Dataset 9,stratified done
# Dataset 30,importance done
# Dataset 38,importance done
# Dataset 28,uniform done
# Dataset 58,importance done
# Dataset 56,uniform done
# Dataset 4,uniform done
# Dataset 12,uniform done
# Dataset 24,uniform done
# Dataset 8,uniform done
# Dataset 0,uniform done
# Dataset 18,importance done
# Dataset 54,importance done
# Dataset 37,stratified done
# Dataset 33,stratified done
# Dataset 22,importance done
# Dataset 2,importance done
# Dataset 6,importance done
# Dataset 48,uniform done
# Dataset 44,uniform done
# Dataset 14,importance done
# Dataset 42,importance done
# Dataset 41,stratified done
# Dataset 49,stratified done
# Dataset 45,stratified done
# Dataset 29,stratified done
# Dataset 57,stratified done
# Dataset 17,stratified done
# Dataset 5,stratified done
# Dataset 1,stratified done
# Dataset 13,stratified done
# Dataset 64,uniform done
# Dataset 62,importance done
# Dataset 61,stratified done
# Dataset 60,uniform done
# Dataset 32,stratified done
# Dataset 20,stratified done
# Dataset 35,uniform done
# Dataset 27,uniform done
# Dataset 40,stratified done
# Dataset 52,stratified done
# Dataset 16,stratified done
# Dataset 47,uniform done
# Dataset 21,importance done
# Dataset 51,uniform done
# Dataset 11,uniform done
# Dataset 36,stratified done
# Dataset 53,importance done
# Dataset 28,stratified done
# Dataset 4,stratified done
# Dataset 56,stratified done
# Dataset 8,stratified done
# Dataset 12,stratified done
# Dataset 24,stratified done
# Dataset 25,importance done
# Dataset 0,stratified done
# Dataset 31,uniform done
# Dataset 59,uniform done
# Dataset 48,stratified done
# Dataset 44,stratified done
# Dataset 33,importance done
# Dataset 49,importance done
# Dataset 55,uniform done
# Dataset 43,uniform done
# Dataset 41,importance done
# Dataset 23,uniform done
# Dataset 45,importance done
# Dataset 57,importance done
# Dataset 32,importance done
# Dataset 39,uniform done
# Dataset 20,importance done
# Dataset 9,importance done
# Dataset 37,importance done
# Dataset 35,stratified done
# Dataset 27,stratified done
# Dataset 40,importance done
# Dataset 52,importance done
# Dataset 64,stratified done
# Dataset 22,uniform done
# Dataset 47,stratified done
# Dataset 29,importance done
# Dataset 51,stratified done
# Dataset 3,uniform done
# Dataset 7,uniform done
# Dataset 16,importance done
# Dataset 15,uniform done
# Dataset 19,uniform done
# Dataset 17,importance done
# Dataset 13,importance done
# Dataset 5,importance done
# Dataset 1,importance done
# Dataset 11,stratified done
# Dataset 54,uniform done
# Dataset 26,uniform done
# Dataset 63,uniform done
# Dataset 60,stratified done
# Dataset 36,importance done
# Dataset 61,importance done
# Dataset 8,importance done
# Dataset 4,importance done
# Dataset 28,importance done
# Dataset 56,importance done
# Dataset 12,importance done
# Dataset 31,stratified done
# Dataset 24,importance done
# Dataset 0,importance done
# Dataset 48,importance done
# Dataset 34,uniform done
# Dataset 33,uniform done
# Dataset 59,stratified done
# Dataset 44,importance done
# Dataset 10,uniform done
# Dataset 21,uniform done
# Dataset 50,uniform done
# Dataset 35,importance done
# Dataset 46,uniform done
# Dataset 42,uniform done
# Dataset 58,uniform done
# Dataset 27,importance done
# Dataset 55,stratified done
# Dataset 22,stratified done
# Dataset 39,stratified done
# Dataset 23,stratified done
# Dataset 43,stratified done
# Dataset 38,uniform done
# Dataset 41,uniform done
# Dataset 53,uniform done
# Dataset 47,importance done
# Dataset 51,importance done
# Dataset 30,uniform done
# Dataset 17,uniform done
# Dataset 26,stratified done
# Dataset 11,importance done
# Dataset 18,uniform done
# Dataset 54,stratified done
# Dataset 3,stratified done
# Dataset 7,stratified done
# Dataset 6,uniform done
# Dataset 19,stratified done
# Dataset 15,stratified done
# Dataset 14,uniform done
# Dataset 64,importance done
# Dataset 2,uniform done
# Dataset 37,uniform done
# Dataset 10,stratified done
# Dataset 34,stratified done
# Dataset 9,uniform done
# Dataset 63,stratified done
# Dataset 57,uniform done
# Dataset 60,importance done
# Dataset 5,uniform done
# Dataset 62,uniform done
# Dataset 68,uniform done
# Dataset 70,importance done
# Dataset 59,importance done
# Dataset 31,importance done
# Dataset 46,stratified done
# Dataset 50,stratified done
# Dataset 25,uniform done
# Dataset 38,stratified done
# Dataset 42,stratified done
# Dataset 65,stratified done
# Dataset 49,uniform done
# Dataset 58,stratified done
# Dataset 45,uniform done
# Dataset 66,importance done
# Dataset 30,stratified done
# Dataset 80,uniform done
# Dataset 74,importance done
# Dataset 13,uniform done
# Dataset 29,uniform done
# Dataset 72,uniform done
# Dataset 1,uniform done
# Dataset 69,stratified done
# Dataset 77,stratified done
# Dataset 81,stratified done
# Dataset 39,importance done
# Dataset 43,importance done
# Dataset 78,importance done
# Dataset 73,stratified done
# Dataset 76,uniform done
# Dataset 55,importance done
# Dataset 23,importance done
# Dataset 18,stratified done
# Dataset 7,importance done
# Dataset 6,stratified done
# Dataset 3,importance done
# Dataset 14,stratified done
# Dataset 15,importance done
# Dataset 19,importance done
# Dataset 84,uniform done
# Dataset 2,stratified done
# Dataset 82,importance done
# Dataset 85,stratified done
# Dataset 65,uniform done
# Dataset 86,importance done
# Dataset 88,uniform done
# Dataset 68,stratified done
# Dataset 89,stratified done
# Dataset 71,uniform done
# Dataset 80,stratified done
# Dataset 90,importance done
# Dataset 94,importance done
# Dataset 92,uniform done
# Dataset 108,uniform done
# Dataset 96,uniform done
# Dataset 100,uniform done
# Dataset 93,stratified done
# Dataset 98,importance done
# Dataset 97,stratified done
# Dataset 63,importance done
# Dataset 106,importance done
# Dataset 104,uniform done
# Dataset 65,importance done
# Dataset 102,importance done
# Dataset 77,importance done
# Dataset 72,stratified done
# Dataset 67,uniform done
# Dataset 61,uniform done
# Dataset 110,importance done
# Dataset 62,stratified done
# Dataset 76,stratified done
# Dataset 112,uniform done
# Dataset 75,uniform done
# Dataset 84,stratified done
# Dataset 69,importance done
# Dataset 73,importance done
# Dataset 114,importance done
# Dataset 116,uniform done
# Dataset 120,uniform done
# Dataset 118,importance done
# Dataset 79,uniform done
# Dataset 122,importance done
# Dataset 124,uniform done
# Dataset 121,stratified done
# Dataset 81,importance done
# Dataset 109,stratified done
# Dataset 113,stratified done
# Dataset 105,stratified done
# Dataset 117,stratified done
# Dataset 85,importance done
# Dataset 101,stratified done
# Dataset 80,importance done
# Dataset 83,uniform done
# Dataset 68,importance done
# Dataset 108,stratified done
# Dataset 88,stratified done
# Dataset 71,stratified done
# Dataset 125,stratified done
# Dataset 87,uniform done
# Dataset 89,importance done
# Dataset 91,uniform done
# Dataset 95,uniform done
# Dataset 92,stratified done
# Dataset 104,stratified done
# Dataset 126,importance done
# Dataset 107,uniform done
# Dataset 96,stratified done
# Dataset 100,stratified done
# Dataset 84,importance done
# Dataset 103,uniform done
# Dataset 93,importance done
# Dataset 67,stratified done
# Dataset 128,uniform done
# Dataset 97,importance done
# Dataset 78,uniform done
# Dataset 111,uniform done
# Dataset 99,uniform done
# Dataset 129,stratified done
# Dataset 112,stratified done
# Dataset 72,importance done
# Dataset 76,importance done
# Dataset 75,stratified done
# Dataset 66,uniform done
# Dataset 116,stratified done
# Dataset 82,uniform done
# Dataset 70,uniform done
# Dataset 74,uniform done
# Dataset 120,stratified done
# Dataset 115,uniform done
# Dataset 79,stratified done
# Dataset 119,uniform done
# Dataset 123,uniform done
# Dataset 124,stratified done
# Dataset 121,importance done
# Dataset 86,uniform done
# Dataset 105,importance done
# Dataset 81,uniform done
# Dataset 113,importance done
# Dataset 117,importance done
# Dataset 109,importance done
# Dataset 108,importance done
# Dataset 101,importance done
# Dataset 69,uniform done
# Dataset 83,stratified done
# Dataset 88,importance done
# Dataset 90,uniform done
# Dataset 104,importance done
# Dataset 85,uniform done
# Dataset 92,importance done
# Dataset 78,stratified done
# Dataset 87,stratified done
# Dataset 128,stratified done
# Dataset 95,stratified done
# Dataset 107,stratified done
# Dataset 96,importance done
# Dataset 82,stratified done
# Dataset 91,stratified done
# Dataset 71,importance done
# Dataset 94,uniform done
# Dataset 98,uniform done
# Dataset 100,importance done
# Dataset 127,uniform done
# Dataset 67,importance done
# Dataset 112,importance done
# Dataset 103,stratified done
# Dataset 125,importance done
# Dataset 99,stratified done
# Dataset 77,uniform done
# Dataset 111,stratified done
# Dataset 74,stratified done
# Dataset 116,importance done
# Dataset 75,importance done
# Dataset 129,importance done
# Dataset 120,importance done
# Dataset 70,stratified done
# Dataset 115,stratified done
# Dataset 73,uniform done
# Dataset 130,importance done
# Dataset 106,uniform done
# Dataset 86,stratified done
# Dataset 66,stratified done
# Dataset 119,stratified done
# Dataset 124,importance done
# Dataset 122,uniform done
# Dataset 79,importance done
# Dataset 123,stratified done
# Dataset 132,uniform done
# Dataset 109,uniform done
# Dataset 118,uniform done
# Dataset 114,uniform done
# Dataset 110,uniform done
# Dataset 102,uniform done
# Dataset 134,importance done
# Dataset 89,uniform done
# Dataset 138,importance done
# Dataset 83,importance done
# Dataset 136,uniform done
# Dataset 133,stratified done
# Dataset 137,stratified done
# Dataset 105,uniform done
# Dataset 90,stratified done
# Dataset 142,importance done
# Dataset 107,importance done
# Dataset 98,stratified done
# Dataset 140,uniform done
# Dataset 128,importance done
# Dataset 93,uniform done
# Dataset 95,importance done
# Dataset 94,stratified done
# Dataset 91,importance done
# Dataset 127,stratified done
# Dataset 101,uniform done
# Dataset 97,uniform done
# Dataset 113,uniform done
# Dataset 103,importance done
# Dataset 126,uniform done
# Dataset 141,stratified done
# Dataset 87,importance done
# Dataset 131,uniform done
# Dataset 106,stratified done
# Dataset 121,uniform done
# Dataset 117,uniform done
# Dataset 111,importance done
# Dataset 144,uniform done
# Dataset 130,uniform done
# Dataset 99,importance done
# Dataset 132,stratified done
# Dataset 148,uniform done
# Dataset 115,importance done
# Dataset 149,stratified done
# Dataset 145,stratified done
# Dataset 123,importance done
# Dataset 122,stratified done
# Dataset 125,uniform done
# Dataset 135,uniform done
# Dataset 119,importance done
# Dataset 110,stratified done
# Dataset 118,stratified done
# Dataset 146,importance done
# Dataset 114,stratified done
# Dataset 139,uniform done
# Dataset 136,stratified done
# Dataset 102,stratified done
# Dataset 150,importance done
# Dataset 133,importance done
# Dataset 137,importance done
# Dataset 152,uniform done
# Dataset 160,uniform done
# Dataset 154,importance done
# Dataset 161,stratified done
# Dataset 140,stratified done
# Dataset 143,uniform done
# Dataset 165,stratified done
# Dataset 162,importance done
# Dataset 129,uniform done
# Dataset 174,importance done
# Dataset 166,importance done
# Dataset 153,stratified done
# Dataset 132,importance done
# Dataset 164,uniform done
# Dataset 144,stratified done
# Dataset 131,stratified done
# Dataset 148,stratified done
# Dataset 168,uniform done
# Dataset 184,uniform done
# Dataset 170,importance done
# Dataset 156,uniform done
# Dataset 127,importance done
# Dataset 158,importance done
# Dataset 135,stratified done
# Dataset 181,stratified done
# Dataset 176,uniform done
# Dataset 173,stratified done
# Dataset 126,stratified done
# Dataset 141,importance done
# Dataset 172,uniform done
# Dataset 157,stratified done
# Dataset 149,importance done
# Dataset 178,importance done
# Dataset 130,stratified done
# Dataset 189,stratified done
# Dataset 169,stratified done
# Dataset 139,stratified done
# Dataset 177,stratified done
# Dataset 180,uniform done
# Dataset 145,importance done
# Dataset 136,importance done
# Dataset 188,uniform done
# Dataset 134,uniform done
# Dataset 182,importance done
# Dataset 185,stratified done
# Dataset 186,importance done
# Dataset 138,uniform done
# Dataset 147,uniform done
# Dataset 165,importance done
# Dataset 184,stratified done
# Dataset 160,stratified done
# Dataset 190,importance done
# Dataset 140,importance done
# Dataset 148,importance done
# Dataset 143,stratified done
# Dataset 155,uniform done
# Dataset 161,importance done
# Dataset 163,uniform done
# Dataset 175,uniform done
# Dataset 152,stratified done
# Dataset 133,uniform done
# Dataset 144,importance done
# Dataset 164,stratified done
# Dataset 151,uniform done
# Dataset 168,stratified done
# Dataset 167,uniform done
# Dataset 131,importance done
# Dataset 142,uniform done
# Dataset 176,stratified done
# Dataset 180,stratified done
# Dataset 192,uniform done
# Dataset 181,importance done
# Dataset 135,importance done
# Dataset 150,uniform done
# Dataset 194,importance done
# Dataset 172,stratified done
# Dataset 134,stratified done
# Dataset 156,stratified done
# Dataset 166,uniform done
# Dataset 189,importance done
# Dataset 184,importance done
# Dataset 173,importance done
# Dataset 188,stratified done
# Dataset 138,stratified done
# Dataset 193,stratified done
# Dataset 146,uniform done
# Dataset 171,uniform done
# Dataset 137,uniform done
# Dataset 153,importance done
# Dataset 139,importance done
# Dataset 160,importance done
# Dataset 149,uniform done
# Dataset 196,uniform done
# Dataset 177,importance done
# Dataset 162,uniform done
# Dataset 182,uniform done
# Dataset 147,stratified done
# Dataset 159,uniform done
# Dataset 141,uniform done
# Dataset 157,importance done
# Dataset 166,stratified done
# Dataset 190,uniform done
# Dataset 191,uniform done
# Dataset 180,importance done
# Dataset 155,stratified done
# Dataset 142,stratified done
# Dataset 143,importance done
# Dataset 185,importance done
# Dataset 185,uniform done
# Dataset 197,stratified done
# Dataset 164,importance done
# Dataset 200,uniform done
# Dataset 198,importance done
# Dataset 168,importance done
# Dataset 152,importance done
# Dataset 175,stratified done
# Dataset 163,stratified done
# Dataset 176,importance done
# Dataset 204,uniform done
# Dataset 145,uniform done
# Dataset 150,stratified done
# Dataset 174,uniform done
# Dataset 201,stratified done
# Dataset 202,importance done
# Dataset 179,uniform done
# Dataset 192,stratified done
# Dataset 183,uniform done
# Dataset 167,stratified done
# Dataset 187,uniform done
# Dataset 188,importance done
# Dataset 169,importance done
# Dataset 195,uniform done
# Dataset 172,importance done
# Dataset 182,stratified done
# Dataset 151,stratified done
# Dataset 205,stratified done
# Dataset 146,stratified done
# Dataset 193,importance done
# Dataset 196,stratified done
# Dataset 190,stratified done
# Dataset 206,importance done
# Dataset 171,stratified done
# Dataset 156,importance done
# Dataset 162,stratified done
# Dataset 191,stratified done
# Dataset 161,uniform done
# Dataset 210,importance done
# Dataset 181,uniform done
# Dataset 209,stratified done
# Dataset 200,stratified done
# Dataset 204,stratified done
# Dataset 178,uniform done
# Dataset 197,importance done
# Dataset 147,importance done
# Dataset 199,uniform done
# Dataset 208,uniform done
# Dataset 214,importance done
# Dataset 154,uniform done
# Dataset 174,stratified done
# Dataset 158,uniform done
# Dataset 186,uniform done
# Dataset 159,stratified done
# Dataset 213,stratified done
# Dataset 212,uniform done
# Dataset 155,importance done
# Dataset 165,uniform done
# Dataset 203,uniform done
# Dataset 218,importance done
# Dataset 201,importance done
# Dataset 192,importance done
# Dataset 205,importance done
# Dataset 196,importance done
# Dataset 204,importance done
# Dataset 189,uniform done
# Dataset 170,uniform done
# Dataset 217,stratified done
# Dataset 177,uniform done
# Dataset 200,importance done
# Dataset 216,uniform done
# Dataset 207,uniform done
# Dataset 195,stratified done
# Dataset 187,stratified done
# Dataset 153,uniform done
# Dataset 163,importance done
# Dataset 211,uniform done
# Dataset 222,importance done
# Dataset 209,importance done
# Dataset 169,uniform done
# Dataset 191,importance done
# Dataset 183,stratified done
# Dataset 194,uniform done
# Dataset 198,uniform done
# Dataset 175,importance done
# Dataset 213,importance done
# Dataset 220,uniform done
# Dataset 179,stratified done
# Dataset 199,stratified done
# Dataset 173,uniform done
# Dataset 215,uniform done
# Dataset 224,uniform done
# Dataset 167,importance done
# Dataset 219,uniform done
# Dataset 151,importance done
# Dataset 171,importance done
# Dataset 178,stratified done
# Dataset 203,stratified done
# Dataset 221,stratified done
# Dataset 186,stratified done
# Dataset 205,uniform done
# Dataset 208,stratified done
# Dataset 206,uniform done
# Dataset 202,uniform done
# Dataset 158,stratified done
# Dataset 212,stratified done
# Dataset 197,uniform done
# Dataset 225,stratified done
# Dataset 226,importance done
# Dataset 157,uniform done
# Dataset 228,uniform done
# Dataset 236,uniform done
# Dataset 201,uniform done
# Dataset 214,uniform done
# Dataset 210,uniform done
# Dataset 193,uniform done
# Dataset 217,importance done
# Dataset 207,stratified done
# Dataset 198,stratified done
# Dataset 159,importance done
# Dataset 154,stratified done
# Dataset 211,stratified done
# Dataset 223,uniform done
# Dataset 232,uniform done
# Dataset 199,importance done
# Dataset 229,stratified done
# Dataset 215,stratified done
# Dataset 170,stratified done
# Dataset 219,stratified done
# Dataset 224,stratified done
# Dataset 230,importance done
# Dataset 216,stratified done
# Dataset 220,stratified done
# Dataset 233,stratified done
# Dataset 206,stratified done
# Dataset 194,stratified done
# Dataset 234,importance done
# Dataset 195,importance done
# Dataset 202,stratified done
# Dataset 203,importance done
# Dataset 187,importance done
# Dataset 179,importance done
# Dataset 238,importance done
# Dataset 183,importance done
# Dataset 237,stratified done
# Dataset 214,stratified done
# Dataset 208,importance done
# Dataset 236,stratified done
# Dataset 210,stratified done
# Dataset 212,importance done
# Dataset 218,uniform done
# Dataset 221,importance done
# Dataset 219,importance done
# Dataset 228,stratified done
# Dataset 207,importance done
# Dataset 211,importance done
# Dataset 232,stratified done
# Dataset 224,importance done
# Dataset 215,importance done
# Dataset 223,stratified done
# Dataset 225,importance done
# Dataset 227,uniform done
# Dataset 220,importance done
# Dataset 216,importance done
# Dataset 229,importance done
# Dataset 231,uniform done
# Dataset 233,importance done
# Dataset 235,uniform done
# Dataset 239,uniform done
# Dataset 236,importance done
# Dataset 237,importance done
# Dataset 209,uniform done
# Dataset 213,uniform done
# Dataset 228,importance done
# Dataset 225,uniform done
# Dataset 218,stratified done
# Dataset 232,importance done
# Dataset 222,uniform done
# Dataset 223,importance done
# Dataset 226,uniform done
# Dataset 217,uniform done
# Dataset 221,uniform done
# Dataset 230,uniform done
# Dataset 227,stratified done
# Dataset 231,stratified done
# Dataset 234,uniform done
# Dataset 239,stratified done
# Dataset 235,stratified done
# Dataset 237,uniform done
# Dataset 238,uniform done
# Dataset 229,uniform done
# Dataset 233,uniform done
# Dataset 226,stratified done
# Dataset 222,stratified done
# Dataset 230,stratified done
# Dataset 239,importance done
# Dataset 227,importance done
# Dataset 231,importance done
# Dataset 234,stratified done
# Dataset 235,importance done
# Dataset 238,stratified done

# %%
import json
with open('fitted-synthetic-color-degree.json','w') as f:
  json.dump(x, f)

# %%
# fit({'id':66, 'sampling':'stratified'}, num_threads=64)

# %%
import json
with open('fitted-synthetic-color-degree.json','r') as f:
  x = json.load(f)

# %%
from collections import Counter
xs = []
ys_s = []
ys_u = []
# np.random.shuffle(x)
for d in x:
  for i in range(20):
    if d['dataset']['sampling'] == 'uniform':
      xs.append(float(d['dataset']['color_ratio']))
      ys_s.append(d['results'][i]['weights'][0])

# %%
import matplotlib.pyplot as plt
plt.plot(xs, ys_s, '.', markersize=1)
plt.plot([7e-5 ,0.7], [np.log(7),np.log(7)], color='grey', linewidth=0.5)
plt.xscale('log')
plt.ylim(1,3)
plt.title('weight of color, 23pos:1neg, color+fitness, log(N+1/s+1)')
# Out:
# Text(0.5,1,'weight of color, 23pos:1neg, color+fitness, log(N+1/s+1)')

# %%
filename = 'nodes=1.0e+05&er_edges=5.0e+05&choice_edges=2.0e+04&color_ratio=1.0e-02&checkpoint=1.00&time=2019-08-02T14:58:30&seed=NGMCEM.npz&extract_time=2019-08-02T23:28:35'
dat = np.load("features/{}.npz".format(filename))

# %%
new_sws = dat['sws_s']

# %%
sampling = 'stratified'
c = sampling[0]
for i in range(15):
  m = MNLogit(num_threads=64)
  m.data(dat['Xs_'+c][i], dat['ys_'+c][i], sws=new_sws[i])
  m.fit(max_num_iter=500, clip=1.0, clip_norm_ord=2)
  print(m.get_model_info())
